# %%
# !pip3 install -U pip setuptools wheel
# !pip3 install -U spacy
# !python3 -m spacy download de_core_news_lg
# !pip3 install numpy
# !pip3 install absl-py
# !pip3 install --upgrade tensorflow
# !pip3 install "tensorflow>=2.0.0"
# !pip3 install --upgrade tensorflow-hub
# !pip3 install tensorflow_text
# !pip3 install --ignore-installed Pillow==9.0.0
# !pip3 install pandas
# !pip3 install xmltodict
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Using cached pip-22.2.2-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (58.0.4)
# Collecting setuptools
#   Using cached setuptools-63.4.1-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: wheel in /opt/anaconda3/lib/python3.9/site-packages (0.37.0)
# Collecting wheel
#   Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.0
#     Uninstalling wheel-0.37.0:
#       Successfully uninstalled wheel-0.37.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 58.0.4
#     Uninstalling setuptools-58.0.4:
#       Successfully uninstalled setuptools-58.0.4
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# Successfully installed pip-22.2.2 setuptools-63.4.1 wheel-0.37.1
# Collecting spacy
#   Using cached spacy-3.4.1-cp39-cp39-macosx_10_9_x86_64.whl (6.6 MB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy) (4.62.3)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.11.3)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.0-cp39-cp39-macosx_10_9_x86_64.whl (783 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-macosx_10_9_x86_64.whl (32 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.9.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from spacy) (63.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy) (21.0)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.7-cp39-cp39-macosx_10_9_x86_64.whl (18 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp39-cp39-macosx_10_9_x86_64.whl (106 kB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.2-py3-none-any.whl (42 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Using cached spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting wasabi<1.1.0,>=0.9.1
#   Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.4-cp39-cp39-macosx_10_9_x86_64.whl (460 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.4)
# Collecting smart-open<6.0.0,>=5.2.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.8-cp39-cp39-macosx_10_9_x86_64.whl (5.9 MB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: wasabi, murmurhash, cymem, typer, spacy-loggers, spacy-legacy, smart-open, preshed, langcodes, catalogue, blis, srsly, pathy, thinc, spacy
# Successfully installed blis-0.7.8 catalogue-2.0.8 cymem-2.0.6 langcodes-3.3.0 murmurhash-1.0.7 pathy-0.6.2 preshed-3.0.6 smart-open-5.2.1 spacy-3.4.1 spacy-legacy-3.0.9 spacy-loggers-1.0.3 srsly-2.4.4 thinc-8.1.0 typer-0.4.2 wasabi-0.10.1
# Collecting de-core-news-lg==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_lg-3.4.0/de_core_news_lg-3.4.0-py3-none-any.whl (567.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.8/567.8 MB 1.5 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from de-core-news-lg==3.4.0) (3.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (2.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (21.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (1.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (4.62.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (63.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (0.6.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (1.0.7)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (2.11.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (8.1.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (1.20.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (3.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (2.4.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /opt/anaconda3/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (1.9.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (4.3.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (1.26.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->de-core-news-lg==3.4.0) (1.1.1)
# Installing collected packages: de-core-news-lg
# Successfully installed de-core-news-lg-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_lg')
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (1.20.3)
# Collecting absl-py
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# Installing collected packages: absl-py
# Successfully installed absl-py-1.2.0
# Collecting tensorflow
#   Using cached tensorflow-2.9.1-cp39-cp39-macosx_10_14_x86_64.whl (228.5 MB)
# Requirement already satisfied: h5py>=2.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.26.0-cp39-cp39-macosx_10_14_x86_64.whl (1.6 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-macosx_10_9_x86_64.whl (13.2 MB)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.0)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.4-cp39-cp39-macosx_10_9_x86_64.whl (961 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: numpy>=1.20 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.20.3)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.47.0-cp39-cp39-macosx_10_10_x86_64.whl (4.4 MB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.3.0)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorboard<2.10,>=2.9
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (63.4.1)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Using cached tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.9.1-py2.py3-none-any.whl (167 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.4)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Installing collected packages: termcolor, tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, oauthlib, keras-preprocessing, grpcio, google-pasta, gast, cachetools, astunparse, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed astunparse-1.6.3 cachetools-5.2.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.9.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.47.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0
# Requirement already satisfied: tensorflow>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (2.9.1)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.12.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (4.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (14.0.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (3.19.4)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.12)
# Requirement already satisfied: numpy>=1.20 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.20.3)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (2.9.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.6.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (63.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (0.26.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.47.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (2.9.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (3.2.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=2.0.0) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2.26.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2.9.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.4.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow>=2.0.0) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (4.8.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (3.2.0)
# Collecting tensorflow-hub
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: numpy>=1.12.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow-hub) (1.20.3)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow-hub) (3.19.4)
# Installing collected packages: tensorflow-hub
# Successfully installed tensorflow-hub-0.12.0
# Collecting tensorflow_text
#   Using cached tensorflow_text-2.9.0-cp39-cp39-macosx_10_9_x86_64.whl (4.4 MB)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow_text) (0.12.0)
# Requirement already satisfied: tensorflow<2.10,>=2.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow_text) (2.9.1)
# Requirement already satisfied: h5py>=2.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (3.2.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.20.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.47.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (63.4.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (2.9.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (14.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (0.26.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.12)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (3.19.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (4.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.2.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (21.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (2.9.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorflow<2.10,>=2.9.0->tensorflow_text) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2.0.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2.9.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (4.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (2021.10.8)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow_text) (3.2.0)
# Installing collected packages: tensorflow_text
# Successfully installed tensorflow_text-2.9.0
# Collecting Pillow==9.0.0
#   Using cached Pillow-9.0.0-cp39-cp39-macosx_10_10_x86_64.whl (3.0 MB)
# Installing collected packages: Pillow
# Successfully installed Pillow-9.0.0
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: xmltodict in /opt/anaconda3/lib/python3.9/site-packages (0.12.0)

# %%
# !pip3 freeze > requirements.txt

# %%
#@title Load the Universal Sentence Encoder's TF Hub module
from absl import logging

import tensorflow as tf
import tensorflow_text
import tensorflow_hub as hub
import numpy as np
import os
import pandas as pd
import re  # RegEx
# import seaborn as sns


import spacy
nlp = spacy.load('de_core_news_lg')

import xmltodict

# %%
import time

# %%
# %%time
module_url = "https://tfhub.dev/google/universal-sentence-encoder-multilingual-large/3" 
#@param ["https://tfhub.dev/google/nnlm-de-dim50-with-normalization/2", 
# "https://tfhub.dev/google/universal-sentence-encoder-multilingual/3"]
model = hub.load(module_url)
print ("module %s loaded" % module_url)
def embed(input):
  return model(input)
# Out:
# 2022-08-04 20:23:03.965132: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# module https://tfhub.dev/google/universal-sentence-encoder-multilingual-large/3 loaded
# CPU times: user 4.61 s, sys: 510 ms, total: 5.12 s
# Wall time: 5.41 s

# %%
# %%time
skills = pd.read_csv('../data/skills_de.csv',usecols=['conceptUri','preferredLabel','description'])
# Out:
# CPU times: user 80.6 ms, sys: 22.8 ms, total: 103 ms
# Wall time: 118 ms

# %%
skills.head(10)
# Out:
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1  http://data.europa.eu/esco/skill/00064735-8fad...
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...
# 3  http://data.europa.eu/esco/skill/0007bdc2-dd15...
# 4  http://data.europa.eu/esco/skill/00090cc1-1f27...
# 5  http://data.europa.eu/esco/skill/000bb1e4-89f0...
# 6  http://data.europa.eu/esco/skill/000c94d2-2a2e...
# 7  http://data.europa.eu/esco/skill/000f1d3d-220f...
# 8  http://data.europa.eu/esco/skill/001115fb-569f...
# 9  http://data.europa.eu/esco/skill/001d46db-035e...
#
#                                       preferredLabel  \
# 0                            Musikpersonal verwalten
# 1              Strafvollzugsverfahren beaufsichtigen
# 2            nicht unterdrückende Praktiken anwenden
# 3  Einhaltung von Vorschriften von Eisenbahnfahrz...
# 4                       verfügbare Dienste ermitteln
# 5                 toxikologische Studien durchführen
# 6         Einheitlichkeit von Kokillen gewährleisten
# 7                                            Haskell
# 8                                  Initiative zeigen
# 9  Personal mit Blick auf die Verringerung von Le...
#
#                                          description
# 0  Zuweisen und Verwalten der Aufgaben des Person...
# 1  Überwachen des Betriebs einer Justizvollzugsan...
# 2  Ermitteln von Repressionen in Gesellschaften, ...
# 3  Kontrollieren von Fahrzeugen, Komponenten und ...
# 4  Ermitteln der verschiedenen verfügbaren Dienst...
# 5  Durchführen von Tests zum Nachweis von Giften ...
# 6  Überwachen der Einheitlichkeit von Kokillen; V...
# 7  Techniken und Grundsätze der Softwareentwicklu...
# 8  Proaktiv sein und den ersten Schritt unternehm...
# 9  Einführung neuer Schulungs- und Personalentwic...

# %%
labels = skills['preferredLabel'].copy(deep=True)
labels
# Out:
# 0                                  Musikpersonal verwalten
# 1                    Strafvollzugsverfahren beaufsichtigen
# 2                  nicht unterdrückende Praktiken anwenden
# 3        Einhaltung von Vorschriften von Eisenbahnfahrz...
# 4                             verfügbare Dienste ermitteln
#                                ...
# 13886    berufliche Leistungsfähigkeit von Nutzern/Nutz...
# 13887             Beleuchtung in Transportgeräten einbauen
# 13888                     Verarbeitung natürlicher Sprache
# 13889                             Bauarbeiten koordinieren
# 13890         Absturzsicherungen und Bordbretter anbringen
# Name: preferredLabel, Length: 13891, dtype: object

# %%
def labels_processing(text):
    processed = []
    for item in text:
        item = nlp(item)
        itemString = ''
        for word in item:
            word = word.lemma_.lower()
            if word != '--' and word != '' and word != ' ':
                if word == '\xa0': continue                    
                itemString += word + ' '
        processed.append(itemString[:-1])
    return processed

# %%
# %%time
processedLabels = labels_processing(labels)
# Out:
# CPU times: user 1min 16s, sys: 766 ms, total: 1min 17s
# Wall time: 1min 19s

# %%
# %%time
test = open('../data/descriptions_cropped.xml','r', encoding='ISO-8859-15').read() # read data
test_dict = xmltodict.parse(test) # parse xml
xmlDict = test_dict
# Out:
# CPU times: user 113 ms, sys: 16.2 ms, total: 130 ms
# Wall time: 131 ms

# %%
# %%time
xml_data = open('../data/FOKUS_AWT_CompetencyExtraction_WB_Brandenburg.xml','r', encoding='ISO-8859-15').read() # read data
xmlDict = xmltodict.parse(xml_data) # parse xml
# Out:
# CPU times: user 7.24 s, sys: 386 ms, total: 7.62 s
# Wall time: 7.78 s

# %%
# %%time
xmlcourses = xmlDict['DEFTISCAT']['COURSETRANSACTIONS']['INSERTCOURSES']['COURSE']
# Out:
# CPU times: user 61.1 ms, sys: 25.1 ms, total: 86.3 ms
# Wall time: 86.9 ms

# %%
# %%time
coursesDict = []
for course in xmlcourses:
    coursesDict.append({"course_id": course['CS_ID'], 
                        "course_name": course['CS_NAME'],
                 "course_description": course['CS_DESC_LONG']})
courses_table = pd.DataFrame(coursesDict)
courses_table.replace([None],value='',inplace=True)
courses = courses_table['course_name'] + ' ' + courses_table['course_description']
# Out:
# CPU times: user 3.75 ms, sys: 2.86 ms, total: 6.6 ms
# Wall time: 7.38 ms

# %%
courses_table
# Out:
#                                course_id  \
# 0   A1E06AAB-F264-4308-F318-2C2E43E1CB54
# 1   A1DFC244-E07B-BE74-4422-1995EE3B5F8A
# 2   A1E08F41-0B47-7D51-C6F5-47D497F050F0
# 3   A1DFF789-1B71-1CD5-F972-9AA4F3B32C8B
# 4   A1E05E65-48FD-DE85-520D-283A9117BCD9
# 5   A1E0969B-12DB-B016-964F-919D1DEB0112
# 6   A1DFDEA2-E36E-E91A-D9B8-3F0956BECDE6
# 7   A1DFEB90-BC08-8DA2-A8A2-30C4C2E6E989
# 8   A1DF7719-5965-53A1-C4CF-22D1AEE3D88B
# 9   A1DF94D9-0547-7ED8-AB3C-6233DFB724AE
# 10  A1DD78D1-C5CC-CB76-91F6-FA3AC74780B0
# 11  A1E07893-73F6-6C44-285C-80EC26E6F55D
# 12  A1DFB21A-E5C1-1E03-CF6A-21A80834E19B
# 13  A1DD8697-1F77-7DCA-4010-76D1AEBDE054
# 14  A06BA7DE-27F8-852E-6B8D-447F09FF6077
# 15  A0C57A36-C189-91B3-E817-ABC41C71401F
# 16  A0CA7A7B-D327-7696-5003-452D53EB3777
# 17  A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861
# 18  A1E00470-9251-11EC-AB1A-357BCD0E40C4
#
#                                           course_name  \
# 0                        Experte im Prozessmanagement
# 1                          Experte in Cloud Computing
# 2             Experte in Investition und Finanzierung
# 3      Experte in Unternehmensaufbau und Organisation
# 4                      Experte in Unternehmensführung
# 5                                IT-Projektmanagement
# 6           PHP Programmierer und Datenbankentwickler
# 7   Programmierung PHP Frameworks: Laravel, Symfon...
# 8                            Shopsystem Administrator
# 9                                Social-Media Manager
# 10  Starte jetzt: Heranführung an die selbstständi...
# 11          Vermarktungsstrategien online und offline
# 12        Webentwicklung 2.0 - HTML5, CSS3, WordPress
# 13  Zukunftswert Mensch: tiefgreifend-wirksame ind...
# 14                     Weiterbildung Wildnispädagogik
# 15  Qualifizierung zur Anerkennung für Erzieher*in...
# 16  Digitales spielbasiertes Lernen - Einsatzmögli...
# 17  Digitales spielbasiertes Lernen - Einsatzmögli...
# 18  Fernlehrgang Fortbildung Aufmaßtechniker*in (ZAB)
#
#                                    course_description
# 0   Die aktuell vorherrschende Situation auf dem A...
# 1   "Cloud Computing" ist die bedarfsabhängige Ber...
# 2   Die aktuell vorherrschende Situation auf dem A...
# 3   Der Kurs zielt auf die Verbesserung der Führun...
# 4   Die aktuell vorherrschende Situation auf dem A...
# 5   Die aktuell vorherrschende Situation auf dem A...
# 6   PHP (Hypertext Preprocessor) ist eine quelloff...
# 7   PHP (Hypertext Preprocessor) ist eine quelloff...
# 8   Ziel der Maßnahme ist es den Teilnehmern eine ...
# 9   Ziel der Maßnahme ist es den Teilnehmern eine ...
# 10  Die Heranführung an die selbstständige Tätigke...
# 11  Die aktuell vorherrschende Situation auf dem A...
# 12  Ziel der Maßnahme ist es den Teilnehmern eine ...
# 13  Die erfolgreiche Integration in den ersten Arb...
# 14  Wir freuen uns mit euch fünf intensive, umfass...
# 15  Seit April 2021 können sich Erzieher*innen mit...
# 16  Teach&Play hat das Ziel, das in Learn&Play ent...
# 17  Sie bringen zur Weiterbildung ein Beispiel aus...
# 18  Die Fortbildung Aufmaßtechniker*in (ZAB) verse...

# %%
courses
# Out:
# 0     Experte im Prozessmanagement Die aktuell vorhe...
# 1     Experte in Cloud Computing "Cloud Computing" i...
# 2     Experte in Investition und Finanzierung Die ak...
# 3     Experte in Unternehmensaufbau und Organisation...
# 4     Experte in Unternehmensführung Die aktuell vor...
# 5     IT-Projektmanagement Die aktuell vorherrschend...
# 6     PHP Programmierer und Datenbankentwickler PHP ...
# 7     Programmierung PHP Frameworks: Laravel, Symfon...
# 8     Shopsystem Administrator Ziel der Maßnahme ist...
# 9     Social-Media Manager Ziel der Maßnahme ist es ...
# 10    Starte jetzt: Heranführung an die selbstständi...
# 11    Vermarktungsstrategien online und offline Die ...
# 12    Webentwicklung 2.0 - HTML5, CSS3, WordPress Zi...
# 13    Zukunftswert Mensch: tiefgreifend-wirksame ind...
# 14    Weiterbildung Wildnispädagogik Wir freuen uns ...
# 15    Qualifizierung zur Anerkennung für Erzieher*in...
# 16    Digitales spielbasiertes Lernen - Einsatzmögli...
# 17    Digitales spielbasiertes Lernen - Einsatzmögli...
# 18    Fernlehrgang Fortbildung Aufmaßtechniker*in (Z...
# dtype: object

# %%
# %%time
length = len(courses)
for i in range(length):
    courses[i] = courses[i].replace('&#8211;','-')
    courses[i] = courses[i].replace('&#8222;','„')
    courses[i] = courses[i].replace('&#8220;','“')
    courses[i] = courses[i].replace('&#8230;','...')
# Out:
# CPU times: user 1.96 ms, sys: 705 µs, total: 2.66 ms
# Wall time: 2.24 ms

# %%
nlp.add_pipe('merge_noun_chunks')
# Out:
# <function spacy.pipeline.functions.merge_noun_chunks(doc: spacy.tokens.doc.Doc) -> spacy.tokens.doc.Doc>

# %%
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner', 'merge_noun_chunks']

# %%
# %%time
def To_sentences(courses):
    courses_sent = []
    courses_sent_lemma = []
    for course in (courses):
        with nlp.select_pipes(disable=['merge_noun_chunks','attribute_ruler', 'ner']):
            doc = nlp(str(course))
            sentences = []
            for sent in doc.sents:
                course_processed = ''
                sents = []
                for word in sent:
                    word = word.text
                    word = word.replace('\n', ' ')
                    word = word.strip().strip('"@#$%^&*§')
                    if word == '-':
                        if course_processed != '':
                            sents.append(course_processed[:-1])
                            course_processed = ''
                        continue
                    if word.startswith('- ') and len(word) > 1:
                        word = word.replace('- ', '')
                        if course_processed != '':
                            sents.append(course_processed[:-1])
                            course_processed = ''
                    if (not re.match('\s+', word,re.I)) and word != '--' and word != '':
                        if "/-" in word: 
                            word = word.split("/-")[0]
                        if re.match(r'\,|\.|\?|\!|\)', word):
                            course_processed = course_processed[:-1] + word + ' '
                        elif re.match(r'\(',word):
                            course_processed += word
                        else:
                            course_processed += word + ' '
                sentences += sents
                if course_processed != '':
                    sentences.append(course_processed[:-1])
            courses_sent_lemma.append(sentences)
    return courses_sent_lemma
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 8.11 µs

# %%
# course_in_sentences_test = To_sentences(courses.iloc[:1])
# print(courses.iloc[0])
# print(course_in_sentences_test)
# Out:
# Experte im Prozessmanagement Die aktuell vorherrschende Situation auf dem Arbeitsmarkt gestaltet sich als wandelbar und schnelllebig. Globalisierung und Technisierung tragen einen großen Anteil dazu bei. Verschiedene Kulturen treffen im Arbeitsleben aufeinander. Verschiedene Abteilungen und Aufgabenbereiche treffen aufeinander. Es wird immer komplexer.
#
# Ziel der Maßnahme Weiterbildung Prozessmanagement ist es deshalb, den Teilnehmenden eine solide Basis auf dem Gebiet des Prozessmanagements zu vermitteln. Welche Fach- und Wissensbereiche dabei unabdingbar sind, haben wir in der Kurzbeschreibung dargestellt.
#
# Unser Verständnis davon, zukünftige Spezialisten im Bereich des Prozessmanagements auszubilden, hat weniger damit zu tun, theoretisches Wissen zu vermitteln, sondern unsere Teilnehmer von Weiterbildung Prozessmanagement in die Lage zu versetzen, als professionelle Prozessmanager in der Praxis auftreten zu können, indem wir ihnen die richtigen Werkzeuge dafür an die Hand geben. Das hat vor allem auch damit zu tun, dass unsere Teilnehmer von Weiterbildung Prozessmanagement in die Lage versetzt werden, sich selbst zu führen und zu organisieren, bevor sie in die Situation kommen, Prozesse in Unternehmen zu analysieren und zu optimieren.
#
# Am Ende dieser Weiterbildung Prozessmanagement wiederholen wir in einem Reflektionstag die erarbeiteten Inhalte und festigen somit zusätzlich die erworbenen fachlichen Inhalte.
# [['Experte im Prozessmanagement', 'Die aktuell vorherrschende Situation auf dem Arbeitsmarkt gestaltet sich als wandelbar und schnelllebig.', 'Globalisierung und Technisierung tragen einen großen Anteil dazu bei.', 'Verschiedene Kulturen treffen im Arbeitsleben aufeinander.', 'Verschiedene Abteilungen und Aufgabenbereiche treffen aufeinander.', 'Es wird immer komplexer.', 'Ziel der Maßnahme', 'Weiterbildung', 'Prozessmanagement ist es deshalb, den Teilnehmenden eine solide Basis auf dem Gebiet des Prozessmanagements zu vermitteln.', 'Welche Fach- und Wissensbereiche dabei unabdingbar sind, haben wir in der Kurzbeschreibung dargestellt.', 'Unser Verständnis davon, zukünftige Spezialisten im Bereich des Prozessmanagements auszubilden, hat weniger damit zu tun, theoretisches Wissen zu vermitteln, sondern unsere Teilnehmer von Weiterbildung Prozessmanagement in die Lage zu versetzen, als professionelle Prozessmanager in der Praxis auftreten zu können, indem wir ihnen die richtigen Werkzeuge dafür an die Hand geben.', 'Das hat vor allem auch damit zu tun, dass unsere Teilnehmer von Weiterbildung Prozessmanagement in die Lage versetzt werden, sich selbst zu führen und zu organisieren, bevor sie in die Situation kommen, Prozesse in Unternehmen zu analysieren und zu optimieren.', 'Am Ende dieser Weiterbildung', 'Prozessmanagement wiederholen wir in einem Reflektionstag die erarbeiteten Inhalte und festigen somit zusätzlich die erworbenen fachlichen Inhalte.']]

# %%
# %%time
def Segment_processing(part_of_the_courses):
    
    # to sentences
    course_in_sentences = To_sentences(part_of_the_courses)
    
    # to chunks
    courses_chunks = []
    for course in course_in_sentences:
        course_chunks = []
        for sent in course:
            sent_chunks = []
            doc = nlp(sent)
            for tok in doc:
                with nlp.select_pipes(disable=['merge_noun_chunks','attribute_ruler', 'ner']):
#                     with nlp.select_pipes(disable=['attribute_ruler', 'ner']):
                    if not re.match('\(|\)|\,|\.|\!|\?|\/',tok.text) and not tok.is_stop: 
                        tok = nlp(tok.text)
                        words = ''
                        for word in tok:
                            if not word.is_stop and word.lemma_ != '--':
                                words = words + word.lemma_ + ' '  
                        sent_chunks.append(words[:-1])
            course_chunks += sent_chunks
        courses_chunks.append(course_chunks)
    return courses_chunks
# Out:
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 10 µs

# %%
# %%time
courses_chunks_test = Segment_processing(courses.iloc[:1])
print(course_in_sentences_test)
print(courses_chunks_test)
# Out:
# [['Experte im Prozessmanagement', 'Die aktuell vorherrschende Situation auf dem Arbeitsmarkt gestaltet sich als wandelbar und schnelllebig.', 'Globalisierung und Technisierung tragen einen großen Anteil dazu bei.', 'Verschiedene Kulturen treffen im Arbeitsleben aufeinander.', 'Verschiedene Abteilungen und Aufgabenbereiche treffen aufeinander.', 'Es wird immer komplexer.', 'Ziel der Maßnahme', 'Weiterbildung', 'Prozessmanagement ist es deshalb, den Teilnehmenden eine solide Basis auf dem Gebiet des Prozessmanagements zu vermitteln.', 'Welche Fach- und Wissensbereiche dabei unabdingbar sind, haben wir in der Kurzbeschreibung dargestellt.', 'Unser Verständnis davon, zukünftige Spezialisten im Bereich des Prozessmanagements auszubilden, hat weniger damit zu tun, theoretisches Wissen zu vermitteln, sondern unsere Teilnehmer von Weiterbildung Prozessmanagement in die Lage zu versetzen, als professionelle Prozessmanager in der Praxis auftreten zu können, indem wir ihnen die richtigen Werkzeuge dafür an die Hand geben.', 'Das hat vor allem auch damit zu tun, dass unsere Teilnehmer von Weiterbildung Prozessmanagement in die Lage versetzt werden, sich selbst zu führen und zu organisieren, bevor sie in die Situation kommen, Prozesse in Unternehmen zu analysieren und zu optimieren.', 'Am Ende dieser Weiterbildung', 'Prozessmanagement wiederholen wir in einem Reflektionstag die erarbeiteten Inhalte und festigen somit zusätzlich die erworbenen fachlichen Inhalte.']]
# [['Experte', 'Prozessmanagement', 'aktuell vorherrschend Situation', 'Arbeitsmarkt', 'gestalten', 'wandelbar', 'schnelllebig', 'Globalisierung', 'Technisierung', 'tragen', 'Anteil', 'verschieden Kultur', 'treffen', 'Arbeitsleben', 'aufeinander', 'verschieden Abteilung', 'Aufgabenbereich', 'treffen', 'aufeinander', 'komplex', 'Ziel', 'Maßnahme', 'Weiterbildung', 'Prozessmanagement', 'Teilnehmenden', 'solide Basis', 'Gebiet', 'Prozessmanagement', 'vermitteln', 'Fach Wissensbereich', 'unabdingbar', 'Kurzbeschreibung', 'darstellen', 'Verständnis', 'zukünftig Spezialist', 'Bereich', 'Prozessmanagement', 'ausbilden', 'theoretisch wissen', 'vermitteln', 'Teilnehmer', 'Weiterbildung', 'Prozessmanagement', 'Lage', 'versetzen', 'professionell Prozessmanager', 'Praxis', 'auftreten', 'richtig Werkzeug', 'Hand', 'geben', 'Teilnehmer', 'Weiterbildung', 'Prozessmanagement', 'Lage', 'versetzen', 'führen', 'organisieren', 'bevor', 'Situation', 'Prozeß', 'Unternehmen', 'analysieren', 'optimieren', 'Weiterbildung', 'Prozessmanagement', 'wiederholen', 'Reflektionstag', 'erarbeitet Inhalt', 'festigen', 'somit', 'zusätzlich', 'erworben fachlich Inhalt']]
# CPU times: user 767 ms, sys: 610 ms, total: 1.38 s
# Wall time: 1.52 s

# %% [markdown]
# ## Embedding-phase

# %%
def Course_Embedding(courses_chunks):
    courses_chunks_embed = []
    for course in courses_chunks:
        courses_chunks_embed.append(embed(course))
    return courses_chunks_embed

# %%
# %%time
labels_embed = embed(processedLabels)
# Out:
# CPU times: user 1min 54s, sys: 36.5 s, total: 2min 30s
# Wall time: 37.8 s

# %% [markdown]
# ## Similarity

# %%
# %%time
def Similarity(labels, courses):
    result = []
    for course in courses:
        result.append(np.dot(labels, np.transpose(course)))
    return result
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs

# %%
# %%time
def Get_relations(relations,skills,courses_table,course_idx,benchmark,courses_chunks):

    idx = 0
    counter = 0

    df_relations = pd.DataFrame(columns = ['conceptUri'])
    for relationship in relations:
        print('course: ', course_idx)
        competency_idx = np.where(relationship>benchmark) 

        print('numbers of extracted competency: ', len(competency_idx[0]))
        for j in range(len(competency_idx[0])):
            print(processedLabels[competency_idx[0][j]],'--', courses_chunks[idx][competency_idx[1][j]])
            
        competency = set(skills.loc[list(competency_idx[0]),'conceptUri'])
        competency_uri = pd.DataFrame(competency,columns=['conceptUri'], index=[courses_table.iloc[course_idx]['course_id']]*len(competency)) 

        print(' ------')
#         print(courses[course_idx])
        print('\n')

        df_relations = pd.concat([df_relations,competency_uri])
    
        course_idx += 1 
        
#         test:
        idx += 1
        counter += len(competency)
    print('number of extracted competency', counter)
    print('\n', df_relations)

    return df_relations
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 6.91 µs

# %%
def Competence_extraction(courses,course_start_idx,labels,benchmark):
    courses_chunks = Segment_processing(courses)
    courses_embed = Course_Embedding(courses_chunks)
    calculated_results = Similarity(labels, courses_embed)
    return Get_relations(calculated_results,skills,courses_table,course_start_idx,benchmark,courses_chunks)

# %%
# %%time
def Save_results(courses,benchmark):
    for i in range(27):
        start = i * 600
        end = (i+1) * 600
        courses_div = courses.iloc[start:end]
        relations = Competence_extraction(courses_div,start,labels_embed,benchmark)
        relations.to_csv(path_or_buf="./relations_part_"+str(i+1)+".csv" ,columns=['conceptUri'], index_label='course_id')
    Competence_extraction(courses.iloc[27*600:],27*600,labels_embed,benchmark).to_csv(path_or_buf="./relations_part_28.csv" ,columns=['conceptUri'], index_label='course_id')
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs

# %%
# %%time
Competence_extraction(courses,0,labels_embed,benchmark=0.83)
# Out:
# course:  0
# numbers of extracted competency:  16
# probe organisieren -- organisieren
# ernte organisieren -- organisieren
# stellenanalyse durchführen -- analysieren
# organisieren arbeiten -- organisieren
# darlehen analysieren -- analysieren
# auftritt organisieren -- organisieren
# arbeitsmarktangebot -- Arbeitsmarkt
# erhebungstechnik -- Technisierung
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  1
# numbers of extracted competency:  3
# datenbank führen -- Datenbankum
# datenbank -- Datenbankum
# internet der ding -- Internet
#  ------
#
#
# course:  2
# numbers of extracted competency:  5
# finanzmarktgeschaft durchführen -- Finanzmarkt
# arbeitsmarktangebot -- Arbeitsmarkt
# erhebungstechnik -- Technisierung
# finanzmarkt -- Finanzmarkt
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  3
# numbers of extracted competency:  11
# arbeitsmarktangebot -- Arbeitsmarkt
# geschäftsprozeß analysieren -- Unternehmensanalyse
# erhebungstechnik -- Technisierung
# business-analyse -- Unternehmensanalyse
# beschaffungsmarktanalyse durchführen -- Marktanalyse
# unternehmensaufbau festlegen -- Unternehmensaufbau
# marketing-grundlag vermitteln -- Marketing
# marktanalyse -- Marktanalyse
# marketingmix -- Marketing
# arbeitsmarkt -- Arbeitsmarkt
# schulungsmarkt analysieren -- Marktanalyse
#  ------
#
#
# course:  4
# numbers of extracted competency:  14
# probe organisieren -- organisieren
# probe organisieren -- organisieren
# ernte organisieren -- organisieren
# ernte organisieren -- organisieren
# samen einbringen -- zusammenbringen
# organisieren arbeiten -- organisieren
# organisieren arbeiten -- organisieren
# auftritt organisieren -- organisieren
# auftritt organisieren -- organisieren
# arbeitsmarktangebot -- Arbeitsmarkt
# arbeit leiten -- arbeiten
# erhebungstechnik -- Technisierung
# staf -- Mitarbeiter
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  5
# numbers of extracted competency:  14
# probe organisieren -- organisieren
# probe organisieren -- organisieren
# ernte organisieren -- organisieren
# ernte organisieren -- organisieren
# organisieren arbeiten -- organisieren
# organisieren arbeiten -- organisieren
# auftritt organisieren -- organisieren
# auftritt organisieren -- organisieren
# finanzmittel verwalten -- Koste Finanzmanagement
# arbeitsmarktangebot -- Arbeitsmarkt
# finanzmanagement -- Koste Finanzmanagement
# erhebungstechnik -- Technisierung
# risikomanagement -- Risikomanagement
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  6
# numbers of extracted competency:  3
# computerprogrammierung -- Programmierung
# php -- PHP
# internet der ding -- Internet
#  ------
#
#
# course:  7
# numbers of extracted competency:  4
# computerprogrammierung -- Programmierung
# php -- PHP
# php -- PHP
# internet der ding -- Internet
#  ------
#
#
# course:  8
# numbers of extracted competency:  14
# stellenanalyse durchführen -- analysieren
# sozial bündnis -- social
# darlehen analysieren -- analysieren
# web-analyse -- Webanalyse
# ertrag verwalten -- verwalten
# ertrag verwalten -- verwalten
# belichter bedienen -- bedienen
# bestellung ausstellen -- Bestellung
# grader bedienen -- bedienen
# stall verwalten -- verwalten
# stall verwalten -- verwalten
# geschäftsprozeß -- Geschäftsprozeß
# schläuch bedienen -- bedienen
# endanschlag anlegen -- anlegen
#  ------
#
#
# course:  9
# numbers of extracted competency:  23
# stellenanalyse durchführen -- analysieren
# sozial bündnis -- social
# sozial bündnis -- social
# sozial bündnis -- social
# sozial bündnis -- social
# sozial bündnis -- social
# sozial bündnis -- social
# darlehen analysieren -- analysieren
# arbeit leiten -- arbeiten
# belichter bedienen -- bedienen
# grader bedienen -- bedienen
# grafikdesign -- Grafikdesigner
# marketing-grundlag vermitteln -- Marketing
# marketing-grundlag vermitteln -- Marketing
# marketing-grundlag vermitteln -- Marketing
# marketing-grundlag vermitteln -- Marketing
# marketing-grundlag vermitteln -- Marketing
# schläuch bedienen -- bedienen
# marketingmix -- Marketing
# marketingmix -- Marketing
# marketingmix -- Marketing
# marketingmix -- Marketing
# marketingmix -- Marketing
#  ------
#
#
# course:  10
# numbers of extracted competency:  5
# arbeitsmarktangebot -- Arbeitsmarkt
# selbstständig arbeiten -- selbstständig Tätigkeit
# selbstständig arbeiten -- selbstständig Tätigkeit
# selbstständig arbeiten -- selbstständig Tätigkeit
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  11
# numbers of extracted competency:  7
# marketingstrategie umsetzen -- Vermarktungsstrategie
# beratung zu marktstrategie leisten -- Vermarktungsstrategie
# arbeitsmarktangebot -- Arbeitsmarkt
# erhebungstechnik -- Technisierung
# marketing-grundlag vermitteln -- Marketing
# marketingmix -- Marketing
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  12
# numbers of extracted competency:  11
# kommunikation -- Kommunikation
# säuglingspflege -- einpflegen
# wordpress -- WordPress
# wordpress -- WordPress
# wordpress -- WordPress
# wordpress -- WordPress
# wordpress -- WordPress
# selbstständig arbeiten -- selbstständig
# entscheidung treffen -- Entscheidung
# css -- CSS3
# css -- CSS
#  ------
#
#
# course:  13
# numbers of extracted competency:  2
# arbeitsmarktangebot -- Arbeitsmarkt
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  14
# numbers of extracted competency:  4
# fremdsprache sprechen -- Sprache
# theaterpädagogik -- pädagogisch
# feuer machen -- Feuermachen
# pädagogik -- pädagogisch
#  ------
#
#
# course:  15
# numbers of extracted competency:  3
# sozial bündnis -- soziale
# sporternährung -- Sport
# sportveranstaltung -- Sport
#  ------
#
#
# course:  16
# numbers of extracted competency:  10
# verkokungsprozess -- Prozess
# sich an veränderung anpassen -- anpassen
# sich an veränderung anpassen -- anpassen
# r -- re
# r -- z.
# r -- re
# sporternährung -- Sport
# lehrmethode anwenden -- verwendet Methode
# docht einsetzen -- einsetzen
# sportveranstaltung -- Sport
#  ------
#
#
# course:  17
# numbers of extracted competency:  6
# verkokungsprozess -- Prozess
# wissenschaftlich recherche durchführen -- Forschung
# sich an veränderung anpassen -- anpassen
# sporternährung -- Sport
# sportveranstaltung -- Sport
# aktuarwissenschaft -- Wissenschaft
#  ------
#
#
# course:  18
# numbers of extracted competency:  2
# geometrie -- Geometrie
# gebäude entwerfen -- Gebäude
#  ------
#
#
# number of extracted competency 117
#
#                                                                               conceptUri
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/06bf62ec-3316...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/1258cc12-37bb...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/18d39e12-b7f5...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/5b6fb4d6-582e...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/05bc7677-5a64...
# ...                                                                                 ...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/485cdafb-3c7f...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/47b49f99-74a3...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/c9f4efcd-e16a...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/21dfab2e-f954...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/7c3cde53-9ff7...
#
# [117 rows x 1 columns]
# CPU times: user 12.8 s, sys: 3.05 s, total: 15.8 s
# Wall time: 8.13 s
#                                                                              conceptUri
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/06bf62ec-3316...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/1258cc12-37bb...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/18d39e12-b7f5...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/5b6fb4d6-582e...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/05bc7677-5a64...
# ...                                                                                 ...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/485cdafb-3c7f...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/47b49f99-74a3...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/c9f4efcd-e16a...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/21dfab2e-f954...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/7c3cde53-9ff7...
#
# [117 rows x 1 columns]

# %%
# %%time
Competence_extraction(courses,0,labels_embed,benchmark=0.825)
# Out:
# course:  0
# numbers of extracted competency:  17
# probe organisieren -- organisieren
# ernte organisieren -- organisieren
# stellenanalysen durchführen -- analysieren
# organisieren arbeiten -- organisieren
# darlehen analysieren -- analysieren
# auftritt organisieren -- organisieren
# arbeitsmarktangebot -- Arbeitsmarkt
# unternehmensinkubation -- Unternehmen
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# prozessorientiert management -- Prozessmanagement
# arbeitsmarkt -- Arbeitsmarkt
# aufführungsstätt organisieren -- organisieren
#  ------
#
#
# course:  1
# numbers of extracted competency:  3
# datenbank führen -- Datenbanke
# datenbank -- Datenbanke
# internet der ding -- Internet
#  ------
#
#
# course:  2
# numbers of extracted competency:  5
# finanzmarktgeschaft durchführen -- Finanzmarkt
# arbeitsmarktangebot -- Arbeitsmarkt
# unternehmensinkubation -- Unternehmen
# finanzmarkt -- Finanzmarkt
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  3
# numbers of extracted competency:  11
# arbeitsmarktangebot -- Arbeitsmarkt
# geschäftsprozeß analysieren -- Unternehmensanalyse
# business-analyse -- Unternehmensanalyse
# unternehmertum -- unternehmerperson
# beschaffungsmarktanalyse durchführen -- Marktanalyse
# unternehmensaufbau festlegen -- Unternehmensaufbau
# marketing-grundlage vermitteln -- Marketing
# marktanalyse -- Marktanalyse
# marketingmix -- Marketing
# arbeitsmarkt -- Arbeitsmarkt
# schulungsmarkt analysieren -- Marktanalyse
#  ------
#
#
# course:  4
# numbers of extracted competency:  22
# probe organisieren -- organisieren
# probe organisieren -- organisieren
# ernte organisieren -- organisieren
# ernte organisieren -- organisieren
# samen einbringen -- zusammenbringen
# organisieren arbeiten -- organisieren
# organisieren arbeiten -- organisieren
# auftritt organisieren -- organisieren
# auftritt organisieren -- organisieren
# arbeitsmarktangebot -- Arbeitsmarkt
# arbeit leiten -- arbeiten
# staf -- Mitarbeiter
# arbeitsmarkt -- Arbeitsmarkt
# aufführungsstätt organisieren -- organisieren
# aufführungsstätt organisieren -- organisieren
# faß zusammenbauen -- zusammenbringen
# unternehmensrichtlini -- Unternehmensführung
# unternehmensrichtlini -- Unternehmensführung
# unternehmensrichtlini -- Unternehmensführung
# unternehmensrichtlini -- Unternehmensführung
# unternehmensrichtlini -- Unternehmensführung
# unternehmensrichtlini -- Unternehmensführung
#  ------
#
#
# course:  5
# numbers of extracted competency:  12
# probe organisieren -- organisieren
# probe organisieren -- organisieren
# ernte organisieren -- organisieren
# ernte organisieren -- organisieren
# organisieren arbeiten -- organisieren
# organisieren arbeiten -- organisieren
# auftritt organisieren -- organisieren
# auftritt organisieren -- organisieren
# arbeitsmarktangebot -- Arbeitsmarkt
# arbeitsmarkt -- Arbeitsmarkt
# aufführungsstätt organisieren -- organisieren
# aufführungsstätt organisieren -- organisieren
#  ------
#
#
# course:  6
# numbers of extracted competency:  6
# computerprogrammierung -- Programmierung
# php -- PHP
# php -- PHP
# php -- PHP
# wordpress -- wordPress
# internet der ding -- Internet
#  ------
#
#
# course:  7
# numbers of extracted competency:  3
# php -- PHP
# wordpress -- wordPress
# internet der ding -- Internet
#  ------
#
#
# course:  8
# numbers of extracted competency:  14
# quersag bedienen -- bedienen
# stellenanalysen durchführen -- analysieren
# sozial bündnis -- social
# darlehen analysieren -- analysieren
# ertrag verwalten -- verwalten
# ertrag verwalten -- verwalten
# belichter bedienen -- bedienen
# bestellung ausstellen -- Bestellung
# grader bedienen -- bedienen
# stall verwalten -- verwalten
# stall verwalten -- verwalten
# geschäftsprozeß -- Geschäftsprozeß
# schläuch bedienen -- bedienen
# endanschlag anlegen -- anlegen
#  ------
#
#
# course:  9
# numbers of extracted competency:  27
# quersag bedienen -- bedienen
# stellenanalysen durchführen -- analysieren
# sozial bündnis -- social
# sozial bündnis -- social
# sozial bündnis -- social
# sozial bündnis -- social
# sozial bündnis -- social
# darlehen analysieren -- analysieren
# arbeit leiten -- arbeiten
# unternehmensinkubation -- Unternehmen
# unternehmensinkubation -- Unternehmen
# belichter bedienen -- bedienen
# grader bedienen -- bedienen
# grafikdesign -- Grafikdesigner
# marketing-grundlage vermitteln -- Marketing
# marketing-grundlage vermitteln -- Marketing
# marketing-grundlage vermitteln -- Marketing
# marketing-grundlage vermitteln -- Marketing
# marketing-grundlage vermitteln -- Marketing
# marketing-grundlage vermitteln -- Marketing
# schläuch bedienen -- bedienen
# marketingmix -- Marketing
# marketingmix -- Marketing
# marketingmix -- Marketing
# marketingmix -- Marketing
# marketingmix -- Marketing
# marketingmix -- Marketing
#  ------
#
#
# course:  10
# numbers of extracted competency:  5
# arbeitsmarktangebot -- Arbeitsmarkt
# selbstständig arbeiten -- selbstständig Tätigkeit
# selbstständig arbeiten -- selbstständig Tätigkeit
# selbstständig arbeiten -- selbstständig Tätigkeit
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  11
# numbers of extracted competency:  7
# marketingstrategie umsetzen -- Vermarktungsstrategie
# arbeitsmarktangebot -- Arbeitsmarkt
# unternehmensinkubation -- Unternehmen
# markteintrittsstrategie -- Vermarktungsstrategie
# marketing-grundlage vermitteln -- Marketing
# marketingmix -- Marketing
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  12
# numbers of extracted competency:  9
# kommunikation -- Kommunikation
# säuglingspflege -- einpflegen
# wordpress -- wordPress
# wordpress -- wordPress
# wordpress -- wordPress
# selbstständig arbeiten -- selbstständig
# entscheidung treffen -- Entscheidung
# css -- CSS3
# css -- CSS
#  ------
#
#
# course:  13
# numbers of extracted competency:  3
# arbeitsmarktangebot -- Arbeitsmarkt
# herdensicherheit gewährleisten -- gewährleisten
# arbeitsmarkt -- Arbeitsmarkt
#  ------
#
#
# course:  14
# numbers of extracted competency:  5
# fremdsprache sprechen -- Sprache
# theaterpädagogik -- pädagogisch
# pädagogik -- pädagogisch
# naturgeschichte -- Natur
# freiwillige unterstützen -- unterstützen
#  ------
#
#
# course:  15
# numbers of extracted competency:  5
# sozial bündnis -- sozial
# sozialmediation -- sozial
# sporternährung -- Sport
# herdensicherheit gewährleisten -- gewährleisten
# sportveranstaltung -- Sport
#  ------
#
#
# course:  16
# numbers of extracted competency:  12
# verkokungsprozess -- Prozess
# sich an veränderung anpassen -- anpassen
# sich an veränderung anpassen -- anpassen
# r -- re
# r -- z.
# r -- re
# sporternährung -- Sport
# lehrmethode anwenden -- verwendet Methode
# docht einsetzen -- einsetzen
# sportveranstaltung -- Sport
# bauweise -- construction
# bauweise -- construction
#  ------
#
#
# course:  17
# numbers of extracted competency:  7
# verkokungsprozess -- Prozess
# wissenschaftlich recherche durchführen -- Forschung
# sich an veränderung anpassen -- anpassen
# sporternährung -- Sport
# sportveranstaltung -- Sport
# aktuarwissenschaft -- Wissenschaft
# wissenschaftlich forschung -- Forschung
#  ------
#
#
# course:  18
# numbers of extracted competency:  2
# gebäude entwerfen -- Gebäude
# qualitätsstandard -- Qualität
#  ------
#
#
# number of extracted competency 126
#
#                                                                               conceptUri
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/61ddacb8-c89f...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/38a5c459-c591...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/e5e48620-8476...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/d9a3cb06-d6e0...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/d5a59ca8-2e91...
# ...                                                                                 ...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/57437c77-18a4...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/47b49f99-74a3...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/c9f4efcd-e16a...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/7c3cde53-9ff7...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/8d4271ca-c9fd...
#
# [126 rows x 1 columns]
# CPU times: user 12.8 s, sys: 3.62 s, total: 16.5 s
# Wall time: 8.22 s
# CPU times: user 12.8 s, sys: 3.62 s, total: 16.5 s
# Wall time: 8.22 s
#                                                                              conceptUri
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/61ddacb8-c89f...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/38a5c459-c591...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/e5e48620-8476...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/d9a3cb06-d6e0...
# A1E06AAB-F264-4308-F318-2C2E43E1CB54  http://data.europa.eu/esco/skill/d5a59ca8-2e91...
# ...                                                                                 ...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/57437c77-18a4...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/47b49f99-74a3...
# A0CA8AEC-98C1-1D6F-1831-FFBC9DE00861  http://data.europa.eu/esco/skill/c9f4efcd-e16a...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/7c3cde53-9ff7...
# A1E00470-9251-11EC-AB1A-357BCD0E40C4  http://data.europa.eu/esco/skill/8d4271ca-c9fd...
#
# [126 rows x 1 columns]
